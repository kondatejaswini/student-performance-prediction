# %% [markdown]
# # Student Performance Prediction & Analytics Notebook
# ## B.Tech Computer Science & Data Science Final Project
#
# This notebook performs exploratory data analysis (EDA), data cleaning validation, and comparative training of machine learning regression and classification models.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, f1_score

# Set visual style
sns.set_theme(style="darkgrid")

# %% [markdown]
# ### 1. Load Dataset

# %%
df = pd.read_csv('../data/processed_data.csv')
df.head()

# %% [markdown]
# ### 2. Summary Statistics & Data Info

# %%
df.info()
df.describe().T

# %% [markdown]
# ### 3. Exploratory Visualizations

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='Attendance', y='Final_Marks', hue='Overall_Performance', palette='Set1')
plt.title('Attendance vs Final Marks')
plt.show()
